# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulkadirturkan/personalprojects-py/blob/main/happy_income_csv_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/em-9EhjTEemU7w7-EFnPcg_7aa34fc018d311e980c2cb6467517117_happyscore_income.csv')

# %%
happy = data['happyScore']
income = data['avg_income']

print(happy)
# Out:
# 0      4.350
# 1      4.033
# 2      6.574
# 3      7.200
# 4      7.284
#        ...
# 106    6.485
# 107    5.360
# 108    4.642
# 109    5.129
# 110    4.610
# Name: happyScore, Length: 111, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(income,happy)
